# %%
import pandas as pd

# %%
price = pd.read_csv("https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/mcD_food_prices.csv")

# %%
calories = pd.read_csv("https://raw.githubusercontent.com/erood/interviewqs.com_code_snippets/master/Datasets/mcD_food_calories.csv")

# %% [markdown]
# Given the following datasets, containing both price and calorie information for McDonald's food items:
#
# McDonald's menu item prices
# McDonald's menu item calories
# Write code to merge the two datasets, calculate the price per calorie of food, and stack rank the foods from the 'best value' (most calories per dollar*) to 'worst value' (least calories per dollar*).
#
# *There are of course nuances in nutritional benefits, protein, etc, but we're simplifying here for the purposes of these definitions and assuming someone wants to optimize purely for cost of calories.

# %%
price['Food'] == calories['Food']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# 57    True
# Name: Food, dtype: bool

# %%
data = price.copy()

# %%
data['Calories'] = calories['Calories']

# %%
data['dollars_per_calories'] = data['Price_USD'] / data['Calories']

# %%
data.sort_values('dollars_per_calories')
# Out:
#                                                  Food  Price_USD  Calories  \
# 57                                    Sausage Biscuit       1.27       430
# 56                                          McChicken       1.07       360
# 55                         Bacon Egg & Cheese Biscuit       1.38       460
# 54                                   Sausage McMuffin       1.27       370
# 53                                       Cheeseburger       1.07       300
# 52                                      Cinnamon Melt       1.70       460
# 51                                          Apple Pie       0.95       250
# 50                                           McDouble       1.49       390
# 49                                Double Cheeseburger       1.70       440
# 48  Shakes (Medium Chocolate, Vanilla, or Strawber...       2.77       693
# 47                                    Sausage Burrito       1.27       300
# 46                                    Sausage Burrito       1.27       300
# 45                              French Fries (Medium)       1.70       340
# 44                Chicken Snack Wrap (Crispy) (Ranch)       1.81       360
# 43                                      Big Breakfast       3.73       740
# 42                         Chicken McNuggets (40 pc.)       9.62      1880
# 41                       Big Breakfast with Hot Cakes       5.66      1090
# 40                           Sausage Biscuit with Egg       2.99       570
# 39                                     Mac Snack Wrap       1.81       330
# 38                         Chicken McNuggets (20 pc.)       5.35       940
# 37                             Hot Cakes with Sausage       3.20       520
# 36                          Steak, Egg & Cheese Bagel       4.16       670
# 35               Chicken Snack Wrap (Grilled) (Ranch)       1.81       290
# 34                                Double Cheeseburger       2.76       440
# 33                   Sausage, Egg & Cheese McGriddles       3.52       560
# 32                                               Cone       1.07       170
# 31                             Bacon Clubhouse Burger       4.80       720
# 30                                          Sweet Tea       1.38       200
# 29                 Double Quarter Pounder with Cheese       5.13       740
# 28                                    Frappes (small)       3.09       440
# 27                          Sausage McMuffin with Egg       3.20       450
# 26                                 Sausage McGriddles       2.99       420
# 25                                        Hash Browns       1.07       150
# 24                                            Parfait       1.07       150
# 23                              Fruit & Maple Oatmeal       2.13       290
# 22                                            Big Mac       4.27       540
# 21                        Quarter Pounder with Cheese       4.06       510
# 20                        Bacon, Egg & Cheese Biscuit       3.41       420
# 19                                           McFlurry       2.56       315
# 18                   Chicken Select Tenders (3 piece)       3.20       384
# 17                     Bacon, Egg & Cheese McGriddles       3.52       420
# 16                              Crispy Chicken Deluxe       4.48       530
# 15                             Southern Style Chicken       4.16       430
# 13                                       Cheeseburger       2.99       300
# 14                                       Egg McMuffin       2.99       300
# 12                                       Orange Juice       2.02       200
# 11                         Chicken McNuggets (10 pc.)       4.80       470
# 10                                          Hamburger       2.66       250
# 9                                        Filet-O-Fish       4.06       380
# 8                  Bacon Ranch Salad (Crispy Chicken)       4.91       450
# 7                                            McDouble       4.27       390
# 6                          Egg White Delight McMuffin       2.99       250
# 5                             Artisan Grilled Chicken       4.48       360
# 4                                   Smoothies (small)       3.09       215
# 3                                        Apple Slices       1.07        70
# 2                   Southwest Salad (Grilled Chicken)       5.13       330
# 1                    Premium McWrap (Grilled Chicken)       4.48       190
# 0                                          Side Salad       1.70        20
#
#     dollars_per_calories
# 57              0.002953
# 56              0.002972
# 55              0.003000
# 54              0.003432
# 53              0.003567
# 52              0.003696
# 51              0.003800
# 50              0.003821
# 49              0.003864
# 48              0.003997
# 47              0.004233
# 46              0.004233
# 45              0.005000
# 44              0.005028
# 43              0.005041
# 42              0.005117
# 41              0.005193
# 40              0.005246
# 39              0.005485
# 38              0.005691
# 37              0.006154
# 36              0.006209
# 35              0.006241
# 34              0.006273
# 33              0.006286
# 32              0.006294
# 31              0.006667
# 30              0.006900
# 29              0.006932
# 28              0.007023
# 27              0.007111
# 26              0.007119
# 25              0.007133
# 24              0.007133
# 23              0.007345
# 22              0.007907
# 21              0.007961
# 20              0.008119
# 19              0.008127
# 18              0.008333
# 17              0.008381
# 16              0.008453
# 15              0.009674
# 13              0.009967
# 14              0.009967
# 12              0.010100
# 11              0.010213
# 10              0.010640
# 9               0.010684
# 8               0.010911
# 7               0.010949
# 6               0.011960
# 5               0.012444
# 4               0.014372
# 3               0.015286
# 2               0.015545
# 1               0.023579
# 0               0.085000
